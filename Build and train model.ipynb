# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
import numpy as np
import pickle

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)


X = X/255.0

model = Sequential()

model.add(Conv2D(16, (3, 3), padding="same", input_shape=X.shape[1:]))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(Conv2D(64, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu")) 
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(128))
model.add(Activation("relu")) 
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(2))
model.add(Activation("softmax")) 

model.compile(loss="sparse_categorical_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])

model.fit(X, y, batch_size=16, epochs=30, validation_split=0.3)
model.save('FireDetection.model')
# Out:
# Train on 5203 samples, validate on 2231 samples
# Epoch 1/30
# 5203/5203 [==============================] - 124s 24ms/sample - loss: 0.6710 - accuracy: 0.7067 - val_loss: 0.4447 - val_accuracy: 0.8023
# Epoch 2/30
# 5203/5203 [==============================] - 124s 24ms/sample - loss: 0.5396 - accuracy: 0.7490 - val_loss: 0.4306 - val_accuracy: 0.8028
# Epoch 3/30
# 5203/5203 [==============================] - 123s 24ms/sample - loss: 0.4688 - accuracy: 0.7832 - val_loss: 0.4817 - val_accuracy: 0.7391
# Epoch 4/30
# 5203/5203 [==============================] - 122s 23ms/sample - loss: 0.4452 - accuracy: 0.7943 - val_loss: 0.5046 - val_accuracy: 0.7996
# Epoch 5/30
# 5203/5203 [==============================] - 125s 24ms/sample - loss: 0.4092 - accuracy: 0.8191 - val_loss: 0.2878 - val_accuracy: 0.8861
# Epoch 6/30
# 5203/5203 [==============================] - 122s 23ms/sample - loss: 0.3648 - accuracy: 0.8474 - val_loss: 0.2750 - val_accuracy: 0.8991
# Epoch 7/30
# 5203/5203 [==============================] - 123s 24ms/sample - loss: 0.3172 - accuracy: 0.8695 - val_loss: 0.2047 - val_accuracy: 0.9180
# Epoch 8/30
# 5203/5203 [==============================] - 123s 24ms/sample - loss: 0.2619 - accuracy: 0.8974 - val_loss: 0.1874 - val_accuracy: 0.9247
# Epoch 9/30
# 5203/5203 [==============================] - 122s 23ms/sample - loss: 0.2411 - accuracy: 0.9039 - val_loss: 0.2469 - val_accuracy: 0.8915
# Epoch 10/30
# 5203/5203 [==============================] - 123s 24ms/sample - loss: 0.2195 - accuracy: 0.9143 - val_loss: 0.1408 - val_accuracy: 0.9449
# Epoch 11/30
# 5203/5203 [==============================] - 122s 23ms/sample - loss: 0.2349 - accuracy: 0.9058 - val_loss: 0.1962 - val_accuracy: 0.9207
# Epoch 12/30
# 5203/5203 [==============================] - 122s 23ms/sample - loss: 0.1952 - accuracy: 0.9281 - val_loss: 0.1396 - val_accuracy: 0.9552
# Epoch 13/30
# 5203/5203 [==============================] - 122s 24ms/sample - loss: 0.2058 - accuracy: 0.9231 - val_loss: 0.1232 - val_accuracy: 0.9534
# Epoch 14/30
# 5203/5203 [==============================] - 122s 23ms/sample - loss: 0.1808 - accuracy: 0.9316 - val_loss: 0.1497 - val_accuracy: 0.9444
# Epoch 15/30
# 5203/5203 [==============================] - 123s 24ms/sample - loss: 0.1934 - accuracy: 0.9298 - val_loss: 0.1411 - val_accuracy: 0.9462
# Epoch 16/30
# 5203/5203 [==============================] - 123s 24ms/sample - loss: 0.1570 - accuracy: 0.9414 - val_loss: 0.1297 - val_accuracy: 0.9561
# Epoch 17/30
# 5203/5203 [==============================] - 124s 24ms/sample - loss: 0.1527 - accuracy: 0.9437 - val_loss: 0.1176 - val_accuracy: 0.9574
# Epoch 18/30
# 5203/5203 [==============================] - 124s 24ms/sample - loss: 0.1688 - accuracy: 0.9395 - val_loss: 0.1482 - val_accuracy: 0.9462
# Epoch 19/30
# 5203/5203 [==============================] - 123s 24ms/sample - loss: 0.1473 - accuracy: 0.9487 - val_loss: 0.1217 - val_accuracy: 0.9502
# Epoch 20/30
# 5203/5203 [==============================] - 123s 24ms/sample - loss: 0.1285 - accuracy: 0.9602 - val_loss: 0.1374 - val_accuracy: 0.9480
# Epoch 21/30
# 5203/5203 [==============================] - 123s 24ms/sample - loss: 0.1038 - accuracy: 0.9639 - val_loss: 0.1192 - val_accuracy: 0.9547
# Epoch 22/30
# 5203/5203 [==============================] - 123s 24ms/sample - loss: 0.0980 - accuracy: 0.9666 - val_loss: 0.1201 - val_accuracy: 0.9619
# Epoch 23/30
# 5203/5203 [==============================] - 123s 24ms/sample - loss: 0.1249 - accuracy: 0.9594 - val_loss: 0.2154 - val_accuracy: 0.9274
# Epoch 24/30
# 5203/5203 [==============================] - 124s 24ms/sample - loss: 0.1544 - accuracy: 0.9443 - val_loss: 0.1283 - val_accuracy: 0.9547
# Epoch 25/30
# 5203/5203 [==============================] - 123s 24ms/sample - loss: 0.1257 - accuracy: 0.9544 - val_loss: 0.1677 - val_accuracy: 0.9422
# Epoch 26/30
# 5203/5203 [==============================] - 122s 23ms/sample - loss: 0.0815 - accuracy: 0.9731 - val_loss: 0.1293 - val_accuracy: 0.9565
# Epoch 27/30
# 5203/5203 [==============================] - 122s 24ms/sample - loss: 0.0834 - accuracy: 0.9750 - val_loss: 0.1439 - val_accuracy: 0.9511
# Epoch 28/30
# 5203/5203 [==============================] - 131s 25ms/sample - loss: 0.0848 - accuracy: 0.9742 - val_loss: 0.1227 - val_accuracy: 0.9628
# Epoch 29/30
# 5203/5203 [==============================] - 146s 28ms/sample - loss: 0.0695 - accuracy: 0.9791 - val_loss: 0.1296 - val_accuracy: 0.9579
# Epoch 30/30
# 5203/5203 [==============================] - 140s 27ms/sample - loss: 0.0755 - accuracy: 0.9739 - val_loss: 0.1323 - val_accuracy: 0.9556
# WARNING:tensorflow:From c:\users\intern.htmhieu\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: FireDetection.model\assets

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 124, 124, 16)      1216
# _________________________________________________________________
# activation (Activation)      (None, 124, 124, 16)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 60, 60, 32)        4640
# _________________________________________________________________
# activation_1 (Activation)    (None, 60, 60, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 26, 26, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 26, 26, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 10816)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1384576
# _________________________________________________________________
# activation_4 (Activation)    (None, 128)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_5 (Activation)    (None, 128)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# _________________________________________________________________
# activation_6 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 1,463,650
# Trainable params: 1,463,138
# Non-trainable params: 512
# _________________________________________________________________
# None
